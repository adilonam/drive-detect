# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load YOLO 11 model (it will download automatically if not present)
model = YOLO('./.yolo/yolo11n.pt')  # nano version for faster inference

# Load the highway traffic image
image_path = 'highway-traffic.webp'
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Run prediction on the image
results = model(image_path)

# Display the original image
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb)
plt.title('Original Highway Traffic Image')
plt.axis('off')

# Display the image with predictions
plt.subplot(1, 2, 2)
annotated_image = results[0].plot()
plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))
plt.title('YOLO 11 Car Detection Results')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# image 1/1 /home/adil/repo/drive-detect/highway-traffic.webp: 480x640 2 persons, 30 cars, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# image 1/1 /home/adil/repo/drive-detect/highway-traffic.webp: 480x640 2 persons, 30 cars, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
